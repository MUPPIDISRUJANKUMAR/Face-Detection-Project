# %% [markdown]
# <a href="https://colab.research.google.com/github/MUPPIDISRUJANKUMAR/Face-Detection-Project/blob/main/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Detection  - Viola-Jones Method**

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1YSiue_HkgabePWSJSk_dfXkc_htbFx68)

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1UzzB3lBsy9ewAv1u03iuAwnnqjdTZE5L)

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1xcz5AM58oplvDsMa4Mx6Oc97THLY5_bx)

# %% [markdown]
# ***Use Adaboost to get the right Features (Filters that has less error rate)***

# %% [markdown]
# **Finally Apply Cascade to skip the non face region and focus filters on face region**

# %%
# !git clone https://github.com/deepanrajm/machine_learning.git
# Out:
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 72650, done.
# remote: Counting objects: 100% (70158/70158), done.
# remote: Compressing objects: 100% (70137/70137), done.
# remote: Total 72650 (delta 61), reused 70076 (delta 18), pack-reused 2492
# Receiving objects: 100% (72650/72650), 121.94 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
# Updating files: 100% (3008/3008), done.

# %%
# !pip uninstall -y opencv-python
# Out:
# Found existing installation: opencv-python 3.4.8.29
# Uninstalling opencv-python-3.4.8.29:
#   Successfully uninstalled opencv-python-3.4.8.29

# %%
# !pip install opencv-python==3.4.8.29
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python==3.4.8.29
#   Using cached opencv_python-3.4.8.29-cp38-cp38-manylinux1_x86_64.whl (28.3 MB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from opencv-python==3.4.8.29) (1.21.6)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-3.4.8.29

# %%
# import the necessary packages
from imutils import paths
import cv2
from google.colab.patches import cv2_imshow

# %%
# load the face detector
detector = cv2.CascadeClassifier("machine_learning/OpenCv/face_detection/cascades/haarcascade_frontalface_default.xml")

image_paths = "machine_learning/OpenCv/face_detection/images/"

# %%
# Loop on images for detecting face
for path in sorted(list(paths.list_images(image_paths))):

	frame = cv2.imread(path)

	gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

	faceRects = detector.detectMultiScale(gray, scaleFactor=1.05, minNeighbors=5, minSize=(30, 30), flags=cv2.CASCADE_SCALE_IMAGE)

	# loop over the faces and draw a rectangle around each
	for (x, y, w, h) in faceRects:
		cv2.rectangle(frame, (x, y), (x + w, y + h), (0,255, 0), 3)

	no_of_face = len(faceRects)

	cv2.putText(frame, "Face Detected -  "+str(no_of_face), (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
	cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F050EEC8C70>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7F050EEC8D00>
# <PIL.Image.Image image mode=RGB size=535x314 at 0x7F050EEC8A30>
